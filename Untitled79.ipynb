# %% [markdown]
# <a href="https://colab.research.google.com/github/Sriram04r/CRT_2026/blob/main/Untitled79.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **(01-07-2026)**

# %%
class TreeNode:
  def __init__(self,data):
    self.data=data
    self.left=None
    self.right=None
root=TreeNode(1)
root.left=TreeNode(2)
root.right=TreeNode(3)
root.left.left=TreeNode(4)
root.left.right=TreeNode(5)
root.right.left=TreeNode(6)
root.right.right=TreeNode(7)
print(root)
print(root.left)
print(root.right)
print(root.left.left.data)
print(root.left.right.data)
print(root.right.left.data)
print(root.right.right.data)
# Out:
# ...
# 4
# 5
# 6
# 7

# %% [markdown]
# Level Order Traversal

# %%
class TreeNode:
  def __init__(self,data):
    self.data=data
    self.left=None
    self.right=None
def BFS(root):
    q=[]
    q.append(root)
    while len(q)!=0:
        size=len(q)
        for i in range(size):
            curr=q.pop(0)
            print(curr.data,end=" ")
            if curr.left!=None:
                q.append(curr.left)
            if curr.right!=None:
                q.append(curr.right)
        print()
root=TreeNode(1)
root.left=TreeNode(2)
root.right=TreeNode(3)
root.left.left=TreeNode(4)
root.left.right=TreeNode(5)
root.right.left=TreeNode(6)
root.right.right=TreeNode(7)
root.right.right.right=TreeNode(8)
BFS(root)
# Out:
# 1
# 2 3
# 4 5 6 7
# 8

# %% [markdown]
# Sum of Level order Traversal

# %%
class TreeNode:
  def __init__(self,data):
    self.data=data
    self.left=None
    self.right=None
def BFS(root):
    q=[]
    q.append(root)
    while len(q)!=0:
        size=len(q)
        sum = 0
        for i in range(size):
            curr=q.pop(0)
            sum+=curr.data
            if curr.left!=None:
                q.append(curr.left)
            if curr.right!=None:
                q.append(curr.right)
        print(sum)
root=TreeNode(1)
root.left=TreeNode(2)
root.right=TreeNode(3)
root.left.left=TreeNode(4)
root.left.right=TreeNode(5)
root.right.left=TreeNode(6)
root.right.right=TreeNode(7)
root.right.right.right=TreeNode(8)
BFS(root)
# Out:
# 1
# 5
# 22
# 8

# %% [markdown]
# Average of Level order Traversal

# %%
class TreeNode:
  def __init__(self,data):
    self.data=data
    self.left=None
    self.right=None
def BFS(root):
    q=[]
    q.append(root)
    while len(q)!=0:
        size=len(q)
        sum = 0
        for i in range(size):
            curr=q.pop(0)
            sum+=curr.data
            if curr.left!=None:
                q.append(curr.left)
            if curr.right!=None:
                q.append(curr.right)
        avg = sum/size
        print(avg)
root=TreeNode(1)
root.left=TreeNode(2)
root.right=TreeNode(3)
root.left.left=TreeNode(4)
root.left.right=TreeNode(5)
root.right.left=TreeNode(6)
root.right.right=TreeNode(7)
root.right.right.right=TreeNode(8)
BFS(root)
# Out:
# 1.0
# 2.5
# 5.5
# 8.0

# %%
def BFS(root):
    q=[]
    q.append(root)
    mlist=[]
    while len(q)!=0:
        size=len(q)
        l=[]
        for i in range(size):
            curr=q.pop(0)
            l.append(curr.data)
            if curr.left!=None:
                q.append(curr.left)
            if curr.right!=None:
                q.append(curr.right)
        mlist.append(l)
    print(mlist)
root=TreeNode(1)
root.left=TreeNode(2)
root.right=TreeNode(3)
root.left.left=TreeNode(4)
root.left.right=TreeNode(5)
root.right.left=TreeNode(6)
root.right.right=TreeNode(7)
root.right.right.right=TreeNode(8)
BFS(root)
# Out:
# [[1], [2, 3], [4, 5, 6, 7], [8]]

# %% [markdown]
# Binary Tree Level order Traversal(Leet code)

# %%
class Solution:
    def levelOrder(self, root):
        if root==None:
            return []
        q=[]
        q.append(root)
        mlist=[]
        while len(q)!=0:
            size=len(q)
            l=[]
            for i in range(size):
                curr=q.pop(0)
                l.append(curr.val)
                if curr.left!=None:
                    q.append(curr.left)
                if curr.right!=None:
                    q.append(curr.right)
            mlist.append(l)
        return mlist
root=TreeNode(1)
root.left=TreeNode(2)
root.right=TreeNode(3)
root.left.left=TreeNode(4)
root.left.right=TreeNode(5)
root.right.left=TreeNode(6)
root.right.right=TreeNode(7)
root.right.right.right=TreeNode(8)
BFS(root)
# Out:
# [[1], [2, 3], [4, 5, 6, 7], [8]]

# %% [markdown]
# Reverse Binary Tree level order Traversal(Leet code)

# %%
class Solution:
    def levelOrder(self, root):
        if root==None:
            return []
        q=[]
        q.append(root)
        mlist=[]
        while len(q)!=0:
            size=len(q)
            l=[]
            for i in range(size):
                curr=q.pop(0)
                l.append(curr.val)
                if curr.left!=None:
                    q.append(curr.left)
                if curr.right!=None:
                    q.append(curr.right)
            mlist.append(l)
        return mlist[::-1]
root=TreeNode(1)
root.left=TreeNode(2)
root.right=TreeNode(3)
root.left.left=TreeNode(4)
root.left.right=TreeNode(5)
root.right.left=TreeNode(6)
root.right.right=TreeNode(7)
root.right.right.right=TreeNode(8)
BFS(root)
# Out:
# [[1], [2, 3], [4, 5, 6, 7], [8]]

# %% [markdown]
# Average of levels in a Binary tree

# %%
class Solution:
    def averageOfLevels(self, root):
        q=[]
        q.append(root)
        l=[]
        while len(q)!=0:
            size=len(q)
            sum=0
            for i in range(size):
                curr=q.pop(0)
                sum+=curr.val
                if curr.left!=None:
                    q.append(curr.left)
                if curr.right!=None:
                    q.append(curr.right)
            l.append(sum/size)
        return l
root=TreeNode(1)
root.left=TreeNode(2)
root.right=TreeNode(3)
root.left.left=TreeNode(4)
root.left.right=TreeNode(5)
root.right.left=TreeNode(6)
root.right.right=TreeNode(7)
root.right.right.right=TreeNode(8)
BFS(root)
# Out:
# [[1], [2, 3], [4, 5, 6, 7], [8]]
