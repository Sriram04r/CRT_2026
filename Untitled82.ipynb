# %% [markdown]
# <a href="https://colab.research.google.com/github/Sriram04r/CRT_2026/blob/main/Untitled82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LEET CODE PROBLEMS - (08-07-2026)**

# %% [markdown]
# 1. Contains duplicated 2.

# %%
class Solution:
    def containsNearbyDuplicate(self, nums, k):
        d={}
        for i in range(len(nums)):
            if nums[i] not in d:
                d[nums[i]]=i
            else:
                pidx=d[nums[i]]
                if abs(i-pidx)<=k:
                    return True
                else:
                    d[nums[i]]=i
        return False
sol = Solution()
sol.containsNearbyDuplicate([1,2,3,1],3)
# Out:
# True

# %% [markdown]
# 2. Find the Index of first occurance in a string.

# %%
class Solution:
    def strStr(self, haystack, needle):
        return haystack.find(needle)
sol = Solution()

# %%
class Solution:
    def strStr(self, haystack, needle):
        for i in range(len(haystack)):
            ch = haystack[i]
            if ch == needle[0]:
                if needle == haystack[i : i + len(needle)]:
                    return i
        return -1
sol = Solution()
print(sol.strStr("hello", "ll"))
# Out:
# 2

# %% [markdown]
# 3. Same Tree

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
      self.val = val
      self.left = left
      self.right = right

class Solution:
    def isSameTree(self, p: TreeNode, q: TreeNode) -> bool:
        if p==None and q==None:
            return True
        if (p==None and q!=None) or (p!=None and q==None):
            return False
        if p.val!=q.val:
            return False
        l=self.isSameTree(p.left,q.left)
        r=self.isSameTree(p.right,q.right)
        if l==True and r==True:
            return True
        else:
            return False
sol = Solution()
p = TreeNode(1)
p.left = TreeNode(2)
p.right = TreeNode(3)
q = TreeNode(1)
q.left = TreeNode(2)
q.right = TreeNode(3)
print(sol.isSameTree(p,q))
# Out:
# True
